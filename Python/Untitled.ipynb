# %%
def verifica(opcoes):
    var1=True
    while var1:
        re = input('Seleciona uma opção: ')
        if re.isdigit():
            for x in opcoes:
                if x == int(re):
                    var1=False
                    return re
        print('Por favor, insira uma opção válida.')
        
def jogo():
    print('VERSÃO 1.1, AUTOR TOMAS FERRANTI')
    nome = input('Qual o nome do seu herói? ')
    print('(1) Guerreiro (2) Arqueiro (3) Mago')
    classe = verifica([1,2,3])
    if classe == 1:
        classenome = 'Guerreiro'
        vida = 10
        atq = 2
    elif classe == 2:
        classenome = 'Arqueiro'
        vida = 8
        atq = 3
    else:
        classenome = 'Mago'
        vida = 6
        atq = 4
    jogar = 1
    gold = 0
    vidapermanente = vida
    while jogar == 1:
        print ('---------------------')
        print ('Bem-vindo ao menu do jogo, ',nome)
        print ('Sua classe é: {}, e seu dinheiro é: {}'.format(classenome,gold))
        print ('Seus pontos de vida atuais é: {}, enquanto seu ataque é: {}'.format(vidapermanente,atq))
        print ('(1) Batalhar')
        print ('(2) Shop')
        print ('(3) Tutorial')
        print ('(4) Sair do jogo')
        opcao = verifica([1,2,3,4])
        if opcao == 1:
            dentrobatalha = 1
            while dentrobatalha == 1:
                vida = vidapermanente
                print('---------------------')
                print('Bem-vindo a arena desafiador')
                print('Escolha uma dessas bestas legendárias para lutar')
                print('(1) Lvl 1: Cerberus: 5 Vida , 1 Ataque, recompensa de 5 de ouro')
                print('(2) Lvl 2: Cerberus: 10 Vida , 2 Ataque, recompensa de 15 de ouro')
                print('(3) Tou dando o fora daqui mermão')
                opcaobatalha = verifica([1,2,3])
                if opcaobatalha == 1:
                    turno = 1
                    vidinimigo = 5
                    ataqueinimigo = 1
                    while vida>0 and vidinimigo>0:
                        print('---------------------')
                        print('Sua vida: {}, vida do inimigo: {}'.format(vida,vidinimigo))
                        print('(1) Atacar')
                        print('(2) Em breve')
                        opcaobatalhadentro = verifica([1,2])
                        if opcaobatalhadentro == 1:
                            vida = vida - ataqueinimigo
                            vidinimigo = vidinimigo - atq
                    if vida>0:                        
                        print('---------------------')
                        print('Você ganhou! Parabeinz')
                        print('---------------------')
                        gold = gold + 5                    
                    elif vidinimigo>0:                        
                        print('---------------------')
                        print('Perdeste')                        
                        print('---------------------')
                    else:              
                        print('---------------------')
                        print('Empatou')                        
                        print('---------------------')
                elif opcaobatalha == 2:
                    turno = 1
                    vidinimigo = 10
                    ataqueinimigo = 2     
                    while vida>0 and vidinimigo>0:
                        print('---------------------')
                        print('Sua vida: {}, vida do inimigo: {}'.format(vida,vidinimgo))
                        print('(1) Atacar')
                        print('(2) Em breve')
                        opcaobatalhadentro = verifica([1,2])
                        if opcaobatalhadentro == 1:
                            vida = vida - ataqueinimigo
                            vidinimigo = vidinimigo - atq  
                    if vida>0:                        
                        print('---------------------')
                        print('Você ganhou! Parabeinz')
                        print('---------------------')
                        gold = gold + 15                    
                    elif vidinimigo>0:                        
                        print('---------------------')
                        print('Perdeste')                        
                        print('---------------------')
                    else:              
                        print('---------------------')
                        print('Empatou')                        
                        print('---------------------')
                else:
                    dentrobatalha = 0
        elif opcao == 2:
            dentroshop = 1
            while dentroshop ==1:
                print ('---------------------')
                print ('Bem-vindo ao shopping, seu dinheiro é: ',gold)
                print ('\"Escolha um item para comprar, caso não tenha dinheiro racha fora\" - Dono do shop')
                print ('(1) Aumentar vida em 2 pontos - 10 dol')
                print ('(2) Aumentar ataque em 1 ponto - 15 dol')
                print ('(3) Sair do Shop')
                opcaoshop = verifica([1,2,3])
                if opcaoshop == 1:
                    if gold >= 10:
                        vidapermanente = vidapermanente + 2
                        gold = gold-10
                    else:
                        print('Sem dinheiro, racha fora')
                elif opcaoshop == 2:
                    if gold >= 15:
                        atq = atq + 1
                        gold = gold-15
                    else:
                        print('Sem dinheiro, racha fora')
                else:
                    dentroshop = 0
        elif opcao == 3:
            print('---------------------')
            print('Esse jogo consiste de um estilo de batalhas em turnos, e tem como condição \nsua vida cair para 0, provocando sua morte.')
        else:
            jogar = 0

# %%
jogo()
# Out:
# VERSÃO 1.1, AUTOR TOMAS FERRANTI
# Qual o nome do seu herói? jdaisodja
# (1) Guerreiro (2) Arqueiro (3) Mago
# Seleciona uma opção: 4
# Por favor, insira uma opção válida.
# Seleciona uma opção: 4
# Por favor, insira uma opção válida.
# Seleciona uma opção: 4
# Por favor, insira uma opção válida.
# Seleciona uma opção: 4
# Por favor, insira uma opção válida.
# Seleciona uma opção: 2
# ---------------------
# Bem-vindo ao menu do jogo,  jdaisodja
# Sua classe é: Mago, e seu dinheiro é: 0
# Seus pontos de vida atuais é: 6, enquanto seu ataque é: 4
# (1) Batalhar
# (2) Shop
# (3) Tutorial
# (4) Sair do jogo
# Seleciona uma opção: 5
# Por favor, insira uma opção válida.
# Seleciona uma opção: 2

# %%
def batalha(hp,atk,nome,hpini,atkini,nomeini):
    permahp = hp
    permahpini = hpini
    while hp>0 and hpini>0
        print('Bem-vindo a arena de luta, ',nome)
        print('Sua vida atual é {}/{}, enquanto seu ataque é {}'.format(hp,permahp,atk))
        print('Seu atual inimigo é {}, com {} de ataque e vida {}/{}'.format(nomeini,atkini,hpini,permahpini))
        print('O que você deseja fazer?')
        print('(1) Atacar')
        print('(2) Em breve')
        resposta = verifica([1])
